# %%
import pandas as pd
import matplotlib.pyplot as plt

# CNN autoL2
df1 = pd.read_csv('./result/01_1e-5.csv')
df2 = pd.read_csv('./result/01_5e-4.csv')
df3 = pd.read_csv('./result/01_1e-4.csv')
df4 = pd.read_csv('./result/01_autoL2.csv')
# df.head()

# CNN autoL2 with batch normalization
bn_df1 = pd.read_csv('./result/02_bn_1e-05.csv')
bn_df2 = pd.read_csv('./result/02_bn_5e-04.csv')
bn_df3 = pd.read_csv('./result/02_bn_1e-04.csv')
bn_df4 = pd.read_csv('./result/02_bn_autoL2.csv')

# CNN autoL2 with percentage modification
pct5_df1 = pd.read_csv('./result/03_autoL2_by5pctg.csv')
pct5_df2 = pd.read_csv('./result/03_autoL2_by5pctg_bn.csv')
pct10_df1 = pd.read_csv('./result/03_autoL2_by10pctg.csv')
pct10_df2 = pd.read_csv('./result/03_autoL2_by10pctg_bn.csv')

# CNN autoL2 with increase/decrease lambda
adv_df1 = pd.read_csv('./result/04_AdvanceL2.csv')
adv_df2 = pd.read_csv('./result/04_AdvanceL2_bn.csv')

# exactly the same as those above, second attempt
adv_df1c = pd.read_csv('./result/04_AdvanceL2_attempt2.csv')
adv_df2c = pd.read_csv('./result/04_AdvanceL2_bn_attempt2.csv')

# CNN autoL2 with increase/decrease lambda plus percentage modification
adv_5_df1 = pd.read_csv('./result/05_AdvanceL2_by5pctg.csv')
adv_5_df2 = pd.read_csv('./result/05_AdvanceL2_by5pctg_bn.csv')

# %%
batch_size = 128
batch_num = int(50000/batch_size) +1
print(batch_num)
# Out:
# 391

# %%
def plot_preparation(my_df, N):
    df = my_df.loc[my_df['steps']==N-1].copy()
    df['test_acc'] = df['test_acc']/100
    return df
    
df1 = plot_preparation(df1, batch_num)
df2 = plot_preparation(df2, batch_num)
df3 = plot_preparation(df3, batch_num)
df4 = plot_preparation(df4, batch_num)

bn_df1 = plot_preparation(bn_df1, batch_num)
bn_df2 = plot_preparation(bn_df2, batch_num)
bn_df3 = plot_preparation(bn_df3, batch_num)
bn_df4 = plot_preparation(bn_df4, batch_num)

pct5_df1 = plot_preparation(pct5_df1, batch_num)
pct5_df2 = plot_preparation(pct5_df2, batch_num)
pct10_df1 = plot_preparation(pct10_df1, batch_num)
pct10_df2 = plot_preparation(pct10_df2, batch_num)

adv_df1 = plot_preparation(adv_df1, batch_num)
adv_df2 = plot_preparation(adv_df2, batch_num)

adv_df1c = plot_preparation(adv_df1c, batch_num)
adv_df2c = plot_preparation(adv_df2c, batch_num)

adv_5_df1 = plot_preparation(adv_5_df1, batch_num)
adv_5_df2 = plot_preparation(adv_5_df2, batch_num)

# %%
fig = plt.figure(figsize = (10,6))
plt.plot(df1['epochs'],
         df1['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'black',
        )
plt.plot(df2['epochs'],
         df2['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'red',
        )
plt.plot(df3['epochs'],
         df3['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'blue',
        )
plt.plot(df4['epochs'],
         df4['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'green',
        )
plt.title('CNN fixed L2, CNN auto L2')
plt.legend(["λ=0.00001" ,"λ=0.0005", "λ=0.0001", "Auto-L2"])
plt.xlabel('Epochs')
plt.ylabel('Test accuracy')
# Out:
# Text(0, 0.5, 'Test accuracy')

# %%
fig = plt.figure(figsize = (10,6))
plt.plot(bn_df1['epochs'],
         bn_df1['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'black',
        )
plt.plot(bn_df2['epochs'],
         bn_df2['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'red',
        )
plt.plot(bn_df3['epochs'],
         bn_df3['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'blue',
        )
plt.plot(bn_df4['epochs'],
         bn_df4['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'green',
        )
plt.title('CNN with batch_normalization fixed L2, CNN auto L2')
plt.legend(["λ=0.00001" ,"λ=0.0005", "λ=0.0001", "Auto-L2"])
plt.xlabel('Epochs')
plt.ylabel('Test accuracy')
# Out:
# Text(0, 0.5, 'Test accuracy')

# %%
# Percentage Modification

# %%
fig = plt.figure(figsize = (10,6))
plt.plot(df4['epochs'],
         df4['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'black',
        )
plt.plot(bn_df4['epochs'],
         bn_df4['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'red',
        )
plt.plot(pct5_df1['epochs'],
         pct5_df1['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'blue',
        )
plt.plot(pct5_df2['epochs'],
         pct5_df2['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'green',
        )
plt.plot(pct10_df1['epochs'],
         pct10_df1['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'yellow',
        )
plt.plot(pct10_df2['epochs'],
         pct10_df2['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'orange',
        )
plt.title('CNN auto L2 with/without batch_normalization')
plt.legend(["without bn", "with bn", "5% without bn", "5% with bn", "10% without bn", "10% with bn"])
plt.xlabel('Epochs')
plt.ylabel('Test accuracy')
# Out:
# Text(0, 0.5, 'Test accuracy')

# %%
# Advanced Modification

# %%
fig = plt.figure(figsize = (10,6))
plt.plot(df4['epochs'],
         df4['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'black',
        )
plt.plot(bn_df4['epochs'],
         bn_df4['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'red',
        )
plt.plot(adv_df1['epochs'],
         adv_df1['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'blue',
        )
plt.plot(adv_df2['epochs'],
         adv_df2['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'green',
        )
plt.title('auto L2 vs adv_auto L2')
plt.legend(["auto L2" ,"auto L2 bn", "adv auto L2", "adv auto L2 bn"])
plt.xlabel('Epochs')
plt.ylabel('Test accuracy')
# Out:
# Text(0, 0.5, 'Test accuracy')

# %%
fig = plt.figure(figsize = (10,6))

plt.plot(adv_df1['epochs'],
         adv_df1['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'blue',
        )
plt.plot(adv_df2['epochs'],
         adv_df2['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'green',
        )
plt.plot(adv_df1c['epochs'],
         adv_df1c['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'black',
        )
plt.plot(adv_df2c['epochs'],
         adv_df2c['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'red',
        )
plt.title('auto L2 vs adv_auto L2')
plt.legend(["adv auto L2" ,"adv auto L2 bn", "adv auto L2 attempt2", "adv auto L2 bn attempt2"])
plt.xlabel('Epochs')
plt.ylabel('Test accuracy')
# Out:
# Text(0, 0.5, 'Test accuracy')

# %%
fig = plt.figure(figsize = (10,6))
plt.plot(df4['epochs'],
         df4['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'black',
        )
plt.plot(bn_df4['epochs'],
         bn_df4['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'red',
        )
plt.plot(adv_df1['epochs'],
         adv_df1['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'blue',
        )
plt.plot(adv_df2['epochs'],
         adv_df2['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'green',
        )
plt.plot(adv_5_df1['epochs'],
         adv_5_df1['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'yellow',
        )
plt.plot(adv_5_df2['epochs'],
         adv_5_df2['test_acc'],
         linestyle = '-',
         linewidth = 1,
         color = 'orange',
        )
plt.title('auto L2 vs adv_auto L2')
plt.legend(["auto L2" ,"auto L2 bn", "adv auto L2", "adv auto L2 bn", "adv auto L2 5%", "adv auto L2 bn 5%"])
plt.xlabel('Epochs')
plt.ylabel('Test accuracy')
# Out:
# Text(0, 0.5, 'Test accuracy')
